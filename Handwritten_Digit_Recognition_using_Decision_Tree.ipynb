# %% [markdown]
# <a href="https://colab.research.google.com/github/AnmolGauravSingh/ML/blob/main/Handwritten_Digit_Recognition_using_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from keras.datasets import mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
x_train.shape,x_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
plt.imshow(x_train[0])

# %%
y_train[0]
# Out:
# 5

# %%
#scaling the data
x_train=x_train/255
x_test=x_test/255
#converting the array into 2d
x_train_flattened = x_train.reshape(60000,28*28)
x_test_flattened = x_test.reshape(10000,28*28)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train_flattened,y_train)
y_pred=model.predict(x_test_flattened)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,10))
sb.heatmap(cm,annot=True,fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
model.score(x_test_flattened,y_test)*100
# Out:
# 87.72999999999999

# %%
print("Initial 10 Truth Values:",y_test[:10])
print("initial 10 Predicted Value:",y_pred[:10])
# Out:
# Initial 10 Truth Values: [7 2 1 0 4 1 4 9 5 9]
# initial 10 Predicted Value: [7 2 1 0 4 1 4 7 5 9]
